# %%
import pandas as pd
import csv

# %%
DB = pd.read_csv('projeto_guaraves.csv')

# %%
DB
# Out:
#         Local Data do sistema Horario do sistema        Data Horario  \
# 0   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 1   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 2   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 3   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 4   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 5   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 6   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 7   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 8   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 9   amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 10  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 11  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 12  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# ...

# %%
def sum1forline(filename):
    with open(filename) as f:
        return sum(1 for line in f)

# %%
count_line = sum1forline('projeto_guaraves.csv')
