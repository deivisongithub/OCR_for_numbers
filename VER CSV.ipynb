# %%
import pandas as pd

# %%
#Lendo dados
dados = pd.read_csv('projeto_guaraves.csv')

# %%
dados.head()
# Out:
#        Local Data do sistema Horario do sistema        Data Horario  \
# 0  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 1  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 2  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 3  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 4  amaratuba      09/02/2022              16:24  01/10/2021   11:32
#
#    Temperatura do exterior(°C)  Sensor de temperatura 4(°C)  \
# 0                        -99.8                         25.0
# 1                        -99.8                         25.0
# 2                        -99.8                         25.0
# 3                        -99.8                         25.0
# 4                        -99.8                         25.0
#
#    Sensor 1 de humidade (%)  Estado do tunel  Sensor de temperatura 1 (°C)  \
# 0                        77              NaN                          28.2
# ...

# %%
dados
# Out:
#             Local Data do sistema Horario do sistema        Data Horario  \
# 0       amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 1       amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 2       amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 3       amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 4       amaratuba      09/02/2022              16:24  01/10/2021   11:32
# ...           ...             ...                ...         ...     ...
# 100975  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 100976  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 100977  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 100978  amaratuba      09/02/2022              16:24  01/10/2021   11:32
# 100979  amaratuba      09/02/2022              16:24  01/10/2021   11:32
#
#         Temperatura do exterior(°C)  Sensor de temperatura 4(°C)  \
# ...

# %%
#Com 3 fotos por segundos, em 6 meses teremos 5.184.000
